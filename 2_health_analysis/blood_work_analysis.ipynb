# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
with open("blood_work.txt", "r") as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt = f"""
You are a medical data extraction assistant.

From the blood report below, extract ALL test values and classify each one as HIGH, LOW, or NORMAL 
based on the reference ranges provided in the report.

Format your response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: range

Blood Report:
{blood_report}
"""

extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print("=== STAGE 1: EXTRACTED VALUES ===")
print(extracted_values)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3879, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3878 try:
# -> 3879     response: GenerateContentResponse = self.client.models.generate_content(
#    3880         **request,
#    3881     )
#    3882 except ClientError as e:
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\models.py:6270, in Models.generate_content(self, model, contents, config)
#    6269 i += 1
# -> 6270 response = self._generate_content(
#    6271     model=model, contents=contents, config=parsed_config_to_call
#    6272 )
#    6274 if not function_map:
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\models.py:4707, in Models._generate_content(self, model, contents, config)
#    4705 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4707 response = self._api_client.request(
#    4708     'post', path, request_dict, http_options
#    4709 )
#    4711 if config is not None and getattr(
#    4712     config, 'should_return_http_response', None
#    4713 ):
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1747, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1744 http_request = self._build_request(
#    1745     http_method, path, request_dict, http_options
#    1746 )
# -> 1747 response = self._request(http_request, http_options, stream=False)
#    1748 response_body = (
#    1749     response.response_stream[0] if response.response_stream else ''
#    1750 )
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1532, in BaseApiClient._request(self, http_request, http_options, stream)
#    1531     retry = tenacity.Retrying(**retry_kwargs)
# -> 1532     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1534 return self._retry(self._request_once, http_request, stream)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\tenacity\__init__.py:393, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     392 if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393     self._add_action_func(lambda rs: rs.outcome.result())
#     394     return
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:447, in Future.result(self, timeout)
#     446 elif self._state == FINISHED:
# --> 447     return self.__get_result()
#     449 self._condition.wait(timeout)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:396, in Future.__get_result(self)
#     395 try:
# --> 396     raise self._exception
#     397 finally:
#     398     # Break a reference cycle with the exception in self._exception
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\_api_client.py:1511, in BaseApiClient._request_once(self, http_request, stream)
#    1510   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr, arg-type]
# -> 1511 errors.APIError.raise_for_response(response)
#    1512 return HttpResponse(
#    1513     response.headers, response if stream else [response.text]
#    1514 )
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\errors.py:173, in APIError.raise_for_response(cls, response)
#     171   response_json = response.body_segments[0].get('error', {})
# --> 173 cls.raise_error(response.status_code, response_json, response)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\google\genai\errors.py:202, in APIError.raise_error(cls, status_code, response_json, response)
#     201 if 400 <= status_code < 500:
# --> 202   raise ClientError(status_code, response_json, response)
#     203 elif 500 <= status_code < 600:
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use models/gemini-3.6-flash for the latest features and improvements.', 'status': 'NOT_FOUND'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleModelNotFoundError                  Traceback (most recent call last)
# Cell In[4], line 14
#      10 Blood Report:
#      11 {blood_report}
#      12 """
#      13
# ---> 14 extraction_response = llm.invoke(extraction_prompt)
#      15 extracted_values = extraction_response.text
#      16
#      17 print("=== STAGE 1: EXTRACTED VALUES ===")
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3280, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    3277         msg = "Tools are already defined.code_execution tool can't be defined"
#    3278         raise ValueError(msg)
# -> 3280 return super().invoke(input, config, stop=stop, **kwargs)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:477, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     463 @override
#     464 def invoke(
#     465     self,
#    (...)    470     **kwargs: Any,
#     471 ) -> AIMessage:
#     472     config = ensure_config(config)
#     473     return cast(
#     474         "AIMessage",
#     475         cast(
#     476             "ChatGeneration",
# --> 477             self.generate_prompt(
#     478                 [self._convert_input(input)],
#     479                 stop=stop,
#     480                 callbacks=config.get("callbacks"),
#     481                 tags=config.get("tags"),
#     482                 metadata=config.get("metadata"),
#     483                 run_name=config.get("run_name"),
#     484                 run_id=config.pop("run_id", None),
#     485                 **kwargs,
#     486             ).generations[0][0],
#     487         ).message,
#     488     )
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1866, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1857 @override
#    1858 def generate_prompt(
#    1859     self,
#    (...)   1863     **kwargs: Any,
#    1864 ) -> LLMResult:
#    1865     prompt_messages = [p.to_messages() for p in prompts]
# -> 1866     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1673, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1670 for i, m in enumerate(input_messages):
#    1671     try:
#    1672         results.append(
# -> 1673             self._generate_with_cache(
#    1674                 m,
#    1675                 stop=stop,
#    1676                 run_manager=run_managers[i] if run_managers else None,
#    1677                 **kwargs,
#    1678             )
#    1679         )
#    1680     except BaseException as e:
#    1681         if run_managers:
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:2011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2009     result = generate_from_stream(iter(chunks))
#    2010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2011     result = self._generate(
#    2012         messages, stop=stop, run_manager=run_manager, **kwargs
#    2013     )
#    2014 else:
#    2015     result = self._generate(messages, stop=stop, **kwargs)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3883, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3879     response: GenerateContentResponse = self.client.models.generate_content(
#    3880         **request,
#    3881     )
#    3882 except ClientError as e:
# -> 3883     _handle_client_error(e, request)
#    3884 except ServerError as e:
#    3885     _handle_server_error(e)
#
# File C:\D-Drive\Z004f2SD\Devops\agentic-ai-tutorial\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:248, in _handle_client_error(e, request)
#     246 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
#     247 if error_type := _CLIENT_ERROR_TYPES.get(e.code):
# --> 248     raise error_type(msg) from e
#     249 raise ChatGoogleGenerativeAIError(msg) from e
#
# GoogleModelNotFoundError: Error calling model 'gemini-2.5-flash' (NOT_FOUND): 404 NOT_FOUND. {'error': {'code': 404, 'message': 'This model models/gemini-2.5-flash is no longer available to new users. Please update your code to use models/gemini-3.6-flash for the latest features and improvements.', 'status': 'NOT_FOUND'}}
